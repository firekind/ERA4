# %%
from session_7 import create_cifar10_dataloaders, MetricsCallback, Model2
import matplotlib.pyplot as plt
from torchvision import transforms
from torchsummary import summary

import lightning as L
from lightning.pytorch.callbacks import TQDMProgressBar

# %%
L.seed_everything(0, workers=True)
model = Model2()
summary(model, input_size=(3, 32, 32))
# Out:
# Seed set to 0
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 16, 32, 32]             448
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#       Conv2dWithBN-4           [-1, 16, 32, 32]               0
#             Conv2d-5           [-1, 16, 32, 32]           2,320
#        BatchNorm2d-6           [-1, 16, 32, 32]              32
#               ReLU-7           [-1, 16, 32, 32]               0
#       Conv2dWithBN-8           [-1, 16, 32, 32]               0
#             Conv2d-9           [-1, 16, 16, 16]           1,040
#       BatchNorm2d-10           [-1, 16, 16, 16]              32
#              ReLU-11           [-1, 16, 16, 16]               0
#      Conv2dWithBN-12           [-1, 16, 16, 16]               0
# ...

# %%
train_loader, test_loader = create_cifar10_dataloaders(
    batch_size=128,
    data_path="../data",
    train_transform=transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize(
                (0.49139968, 0.48215841, 0.44653091),
                (0.24703223, 0.24348513, 0.26158784),
            ),
        ]
    ),
    test_transform=transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize(
                (0.49139968, 0.48215841, 0.44653091),
                (0.24703223, 0.24348513, 0.26158784),
            ),
        ]
    ),
)

# %%
metrics = MetricsCallback()
trainer = L.Trainer(
    max_epochs=20,
    logger=False,
    enable_checkpointing=False,
    callbacks=[TQDMProgressBar(leave=True), metrics],
)
trainer.fit(model=model, train_dataloaders=train_loader, val_dataloaders=test_loader)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | block1    | Sequential         | 3.9 K  | train
# 1 | block2    | Sequential         | 27.5 K | train
# 2 | block3    | Sequential         | 61.5 K | train
# 3 | train_acc | MulticlassAccuracy | 0      | train
# 4 | val_acc   | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 92.9 K    Trainable params
# 0         Non-trainable params
# 92.9 K    Total params
# 0.371     Total estimated model params size (MB)
# 44        Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# ...
# Epoch 19: 100%|██████████| 391/391 [00:02<00:00, 132.05it/s, val_loss=0.899, val_acc=0.682, train_loss=0.739, train_acc=0.737]
# `Trainer.fit` stopped: `max_epochs=20` reached.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
metrics.plot_loss(ax1)
metrics.plot_accuracy(ax2)
plt.show()

# %% [markdown]
# **Target**
#
# Fix overfitting.
#
# **Result**
#
# Took [`Model1`](../src/session_7/model_1.py) and added dropout
#
# Parameter Count: 92,874 (no change)
#
# Train Accuracy: 73.7%
#
# Test Accuracy: 68.2%
#
# **Analysis**
#
# Reduced the overfitting. Although not completely gone, the gap between train and test accuracy has reduced a lot compared to before. Adding augmentations would help cover the gap. The next thing to do would be to compare this architecture (slowly increase channel size) to a pyramid type architecture, As the last convolution layer drops from 64 channels to 10 channels, which is a bit concerning.
